# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.random.random(size=len(x))

fig, ax = plt.subplots()
# Change the markers to be big red x's
ax.plot(x, y, 'x', ms=18.0, color='r')
plt.show()
