# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
y = np.random.random(size=len(x))
plt.plot(x, y);

# %%
plt.plot(x, y, '.');

# %%
# plt.savefig('myfig.pdf') THIS DID NOT WORK -- SAVED A BLANK PDF
